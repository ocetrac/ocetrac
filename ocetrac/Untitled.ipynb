# %%
import s3fs
import xarray as xr

endpoint_url = 'https://ncsa.osn.xsede.org'
fs_osn = s3fs.S3FileSystem(anon=True, client_kwargs={'endpoint_url': endpoint_url},) 

path = "Pangeo/pangeo-forge/noaa_oisst/v2.1-avhrr.zarr"
ds = xr.open_zarr(fs_osn.get_mapper(path), consolidated=True).resample(time='MS').mean()

ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, time: 478, zlev: 1)
# Coordinates:
#   * time     (time) datetime64[ns] 1981-09-01 1981-10-01 ... 2021-06-01
#   * lat      (lat) float32 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float32 0.125 0.375 0.625 0.875 ... 359.1 359.4 359.6 359.9
#   * zlev     (zlev) float32 0.0
# Data variables:
#     anom     (time, zlev, lat, lon) float32 dask.array<chunksize=(1, 1, 720, 1440), meta=np.ndarray>
#     err      (time, zlev, lat, lon) float32 dask.array<chunksize=(1, 1, 720, 1440), meta=np.ndarray>
#     ice      (time, zlev, lat, lon) float32 dask.array<chunksize=(1, 1, 720, 1440), meta=np.ndarray>
#     sst      (time, zlev, lat, lon) float32 dask.array<chunksize=(1, 1, 720, 1440), meta=np.ndarray>

# %%
timedim = 'time'
xdim = 'lon'
ydim = 'lat'

# %%
da = ds.sst.isel(zlev=0, time=slice(0,100))
da = da.transpose(ydim,timedim, xdim)
da.shape
# Out:
# (720, 100, 1440)

# %%
da = ds.sst.isel(time=slice(0,100))
da = da.transpose(ydim, 'zlev', timedim, xdim)
da.shape
# Out:
# (720, 1, 100, 1440)

# %%
if ((timedim, ydim, xdim) != da.dims) & (len(da.dims)!=3):        
    raise ValueError('Ocetrac currently only supports 3D DataArrays. The dimensions should only contain time, x, and y positions.')

# %%
timedim = 'time'
xdim = 'lon'
ydim = 'lat'

print(da.dims)
print(da.shape)

if ((timedim, ydim, xdim) != da.dims):
    try:
        da = da.transpose(timedim, ydim, xdim) 
    except:
        raise ValueError('Ocetrac currently only supports 3D DataArrays. The dimensions should contain time, x, and y.')
# Out:
# ('lat', 'zlev', 'time', 'lon')
# (720, 1, 100, 1440)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-91d3b4bd6b57> in <module>
#       9     try:
# ---> 10         da = da.transpose(timedim, ydim, xdim)
#      11     except:
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/core/dataarray.py in transpose(self, transpose_coords, *dims)
#    2153         if dims:
# -> 2154             dims = tuple(utils.infix_dims(dims, self.dims))
#    2155         variable = self.variable.transpose(*dims)
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/xarray/core/utils.py in infix_dims(dims_supplied, dims_all)
#     725         if set(dims_supplied) ^ set(dims_all):
# --> 726             raise ValueError(
#     727                 f"{dims_supplied} must be a permuted list of {dims_all}, unless `...` is included"
#
# ...

# %%
da.shape
# Out:
# (100, 720, 1440)

# %%
da.shape
# Out:
# (100, 720, 1440)
